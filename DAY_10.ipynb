# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthanarayana10-cell/SVPS-UN-B1-PTG1/blob/main/DAY_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Functions with Outputs
#
# We will decide the output

# %%
# Function

def my_function():
  # Do this
  # Then do this
  # Finally do this

# %%
# Function with Inputs

def my_function(something):
  # Do this with something
  # Then do this
  # Finally do this

# %%
# Function with Outputs

def my_function():
  result = 3*2
  return result

# %%
# Function with Outputs

def my_function():
  return 3*2

# %%
output = my_function()
print(output)
# Out:
# 6

# %% [markdown]
# How to convert Strings to Title
#
# https://stackoverflow.com/questions/8347048/how-to-convert-string-to-title-case-in-python

# %%
# Convert string to Title Case
# e.g HELLO,hello,hELlo --> Hello

def format_name(f_name,l_name):
  formatted_f_name = f_name.title()
  formatted_l_name = l_name.title()

  # print(f"{formatted_f_name} {formatted_l_name}")
  return f"{formatted_f_name} {formatted_l_name}"

# %%
format_name("amrutha","narayana")
# Out:
# 'Amrutha Narayana'

# %%
print(format_name("amrutha","narayana"))
# Out:
# Amrutha Narayana

# %%
formatted_string = format_name("amrutha","narayana")
print(formatted_string)
# Out:
# Amrutha Narayana

# %%
def function_1(text):
  return text + text

output = function_1("area")
print(output)
# Out:
# areaarea

# %%
def function_2(text):
  return text.title()

function_2("radha krishna")
# Out:
# 'Radha Krishna'

# %%
output = function_2(function_1("area"))
print(output)
# Out:
# Areaarea

# %% [markdown]
# Multiple return values
#
# https://gist.github.com/TheMuellenator/e7e5b21c1314743accfde03c3d239581

# %%
def format_name(f_name,l_name):
  formatted_f_name = f_name.title()
  formatted_l_name = l_name.title()

  print("This got printed")
  return f"{formatted_f_name} {formatted_l_name}"

# Storing output in a variable.
formatted_name = format_name("kritin","vyaas")
print(formatted_name)
# Out:
# This got printed
# Kritin Vyaas

# %%
# print stmt doesn't execute as it is after return stmt.


def format_name(f_name,l_name):
  formatted_f_name = f_name.title()
  formatted_l_name = l_name.title()

  return f"{formatted_f_name} {formatted_l_name}"
  print("This got printed")
  # print stmt doesn't execute as it is after return stmt.

formatted_name = format_name("kritin","vyaas")
print(formatted_name)
# Out:
# Kritin Vyaas

# %%
def format_name(f_name,l_name):
  # if f_name =="" or l_name =="":
  #   return "You did not provide valid inputs"

  formatted_f_name = f_name.title()
  formatted_l_name = l_name.title()

  return f"Result: {formatted_f_name} {formatted_l_name}"
  print("This got printed")
  # print stmt doesn't execute as it is after return stmt.

# For printing output directly.
formatted_name = print(format_name(input("What's your first name?"),input("what's your last name?"))  )
# Out:
# What's your first name?ammu
# what's your last name?varshi
# Result: Ammu Varshi

# %%
# if f_name or l_name is not given , it returns invalid output.

# return as an early exit.
def format_name(f_name,l_name):
  if f_name =="" or l_name =="":
    return "You did not provide valid inputs"

  formatted_f_name = f_name.title()
  formatted_l_name = l_name.title()

  return f"Result: {formatted_f_name} {formatted_l_name}"
  print("This got printed")


formatted_name = print(format_name(input("What's your first name?"),input("what's your last name?"))  )

# %% [markdown]
# leap year flowchart
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Leap Year:
# 💪 This is a difficult challenge! 💪
#
# Write a program that returns True or False whether if a given year is a leap year.
#
# A normal year has 365 days, leap years have 366, with an extra day in February. The reason why we have leap years is really fascinating, this video does it more justice
#
#
#
# This is how you work out whether if a particular year is a leap year.
#
# - on every year that is divisible by 4 with no remainder
#
# - except every year that is evenly divisible by 100 with no remainder
#
# - unless the year is also divisible by 400 with no remainder
#
# e.g. The year 2000:
#
# 2000 ÷ 4 = 500 (Leap)
# 2000 ÷ 100 = 20 (Not Leap)
# 2000 ÷ 400 = 5 (Leap!)
# So the year 2000 is a leap year.
#
#
#
# But the year 2100 is not a leap year because:
#
# 2100 ÷ 4 = 525 (Leap)
# 2100 ÷ 100 = 21 (Not Leap)
# 2100 ÷ 400 = 5.25 (Not Leap)
#
# Warning
#
# Your return should be a boolean and match the Example Output format exactly, including spelling and punctuation.
#
#
#
# Example Input 1
#
# 2400
#
# Example Return 1
#
# True
#
#
#
# Example Input 2
#
# 1989
#
# Example Return 2
#
# False

# %%
def is_leap_year(year):

    if year % 4 == 0 :
        if year % 100 == 0:
            if year % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

# %%
is_leap_year(1994)
# Out:
# False

# %%
is_leap_year(1700)
# Out:
# False

# %% [markdown]
# Docstrings

# %%
# Docstrings


def format_name(f_name,l_name):
  """print stmt doesn't execute as it is after return stmt.
  print stmt doesn't execute as it is after return stmt."""

  formatted_f_name = f_name.title()
  formatted_l_name = l_name.title()

  return f"{formatted_f_name} {formatted_l_name}"
  print("This got printed")


formatted_name = format_name("kritin","vyaas")

length = len(formatted_name)

# %%
# What would you predict to be the result of running the following code?

def outer_function(a, b):
    def inner_function(c, d):
        return c + d
    return inner_function(a, b)

# Your choice of '15' is correct because in the outer_function,
# the values 5 and 10 are passed as parameters a and b,
# which are then used as arguments c and d in inner_function.
# The inner_function computes the sum of 5 and 10, resulting in 15,
#  which is returned as the output of outer_function.

result = outer_function(5, 10)
print(result)
# Out:
# 15

# %% [markdown]
# DAY-10 Project: The calculator Project

# %%
calc_logo = r"""
     _____________________
    |  _________________  |
    | | Python Calc   0. | |
    | |_________________| |
    |  ___ ___ ___   ___  |
    | | 7 | 8 | 9 | | + | |
    | |___|___|___| |___| |
    | | 4 | 5 | 6 | | - | |
    | |___|___|___| |___| |
    | | 1 | 2 | 3 | | x | |
    | |___|___|___| |___| |
    | | . | 0 | = | | / | |
    | |___|___|___| |___| |
    |_____________________|
    """

# %%
def add(n1, n2):
  return n1 + n2

# my_fav_operator =add

# TODO-1: Write the other 3 functions - subtract, multiply, and divide.

def subtract(n1, n2):
  return n1 - n2

def multiply(n1, n2):
  return n1 * n2

def divide(n1, n2):
  return n1 / n2

# TODO-2: Add these 4 functions into a dictionary as the values.Keys = "+", "-", "*", "/"

operations ={
    "+": add,
    "-": subtract,
    "*": multiply,
    "/": divide,

}

# TODO-3: Use the dictionary operations to perform the calculations.Multiply 4*8 using dictionaries.

# print(operations["*"](4,8))


def calculator():
  print(calc_logo)
  should_accumulate = True
  num1 = float(input("Enter a number: "))

  while should_accumulate:
    for symbol in operations:
      print(symbol)
    operation_symbol = input("Pick an operator: ")
    num2 =float(input("Enter next number:"))
    answer = operations[operation_symbol](num1,num2)
    print(f"{num1} {operation_symbol} {num2} = {answer}")

    choice =input(f"Type 'y' to continue calculating with {answer}, or type 'n' to start a new calculation.").lower()

    if choice =="y":
      num1 = answer
    else:
      should_accumulate = False
      print("\n" * 20)
      calculator()



calculator()
# Out:
#      _____________________
#     |  _________________  |
#     | | Python Calc   0. | |
#     | |_________________| |
#     |  ___ ___ ___   ___  |
#     | | 7 | 8 | 9 | | + | |
#     | |___|___|___| |___| |
#     | | 4 | 5 | 6 | | - | |
#     | |___|___|___| |___| |
#     | | 1 | 2 | 3 | | x | |
#     | |___|___|___| |___| |
#     | | . | 0 | = | | / | |
#     | |___|___|___| |___| |
#     |_____________________|
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8742/570883599.py in <cell line: 0>()
#      54
#      55
# ---> 56 calculator()
#
# /tmp/ipykernel_8742/570883599.py in calculator()
#      33   print(calc_logo)
#      34   should_accumulate = True
# ---> 35   num1 = float(input("Enter a number: "))
#      36
#      37   while should_accumulate:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
